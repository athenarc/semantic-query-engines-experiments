# %%
import pandas as pd

import lotus
from lotus.models import LM, CrossEncoderReranker, SentenceTransformersRM

lm = LM(model="ollama/gemma3:12b")
rm = SentenceTransformersRM(model="intfloat/e5-base-v2")
reranker = CrossEncoderReranker(model="mixedbread-ai/mxbai-rerank-large-v1")

lotus.settings.configure(lm=lm, rm=rm, reranker=reranker)
df_players = pd.read_csv("../../datasets/reports_with_players_100.csv")
df_players = df_players[df_players["Game ID"] < 14] # Keep total of ~100 entries
df_players = df_players[['Game ID', 'Report']]

df = df_players.sem_index("Report", "sem_index").sem_searcH("Report", "Which report is referring to Bucks?", K=4, n_rerank=2)

print(df)
# Out:
# 2025-09-22 12:18:22,140 - INFO - Use pytorch device_name: cuda
# 2025-09-22 12:18:22,141 - INFO - Load pretrained SentenceTransformer: intfloat/e5-base-v2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/transformers/modeling_utils.py:3854, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3840 cached_file_kwargs = {
#    3841     "cache_dir": cache_dir,
#    3842     "force_download": force_download,
#    (...)
#    3852     "_commit_hash": commit_hash,
#    3853 }
# -> 3854 resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3856 # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    3857 # result when internet is up, the repo and revision exist, but the file does not.
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/transformers/utils/hub.py:342, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     340 try:
#     341     # Load from URL or cache if already cached
# --> 342     resolved_file = hf_hub_download(
#     343         path_or_repo_id,
#     344         filename,
#     345         subfolder=None if len(subfolder) == 0 else subfolder,
#     346         repo_type=repo_type,
#     347         revision=revision,
#     348         cache_dir=cache_dir,
#     349         user_agent=user_agent,
#     350         force_download=force_download,
#     351         proxies=proxies,
#     352         resume_download=resume_download,
#     353         token=token,
#     354         local_files_only=local_files_only,
#     355     )
#     356 except GatedRepoError as e:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/huggingface_hub/file_download.py:1008, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1007 else:
# -> 1008     return _hf_hub_download_to_cache_dir(
#    1009         # Destination
#    1010         cache_dir=cache_dir,
#    1011         # File info
#    1012         repo_id=repo_id,
#    1013         filename=filename,
#    1014         repo_type=repo_type,
#    1015         revision=revision,
#    1016         # HTTP info
#    1017         endpoint=endpoint,
#    1018         etag_timeout=etag_timeout,
#    1019         headers=hf_headers,
#    1020         proxies=proxies,
#    1021         token=token,
#    1022         # Additional options
#    1023         local_files_only=local_files_only,
#    1024         force_download=force_download,
#    1025     )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/huggingface_hub/file_download.py:1159, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1158 with WeakFileLock(lock_path):
# -> 1159     _download_to_tmp_and_move(
#    1160         incomplete_path=Path(blob_path + ".incomplete"),
#    1161         destination_path=Path(blob_path),
#    1162         url_to_download=url_to_download,
#    1163         proxies=proxies,
#    1164         headers=headers,
#    1165         expected_size=expected_size,
#    1166         filename=filename,
#    1167         force_download=force_download,
#    1168         etag=etag,
#    1169         xet_file_data=xet_file_data,
#    1170     )
#    1171     if not os.path.exists(pointer_path):
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/huggingface_hub/file_download.py:1708, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1707     logger.info("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1708     xet_get(
#    1709         incomplete_path=incomplete_path,
#    1710         xet_file_data=xet_file_data,
#    1711         headers=headers,
#    1712         expected_size=expected_size,
#    1713         displayed_filename=filename,
#    1714     )
#    1715 else:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/huggingface_hub/file_download.py:627, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     625     progress.update(progress_bytes)
# --> 627 download_files(
#     628     xet_download_info,
#     629     endpoint=connection_info.endpoint,
#     630     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     631     token_refresher=token_refresher,
#     632     progress_updater=[progress_updater],
#     633 )
#
# RuntimeError: Data processing error: CAS service error : IO Error: No space left on device (os error 28)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 7
#       4 from lotus.models import LM, CrossEncoderReranker, SentenceTransformersRM
#       6 lm = LM(model="ollama/gemma3:12b")
# ----> 7 rm = SentenceTransformersRM(model="intfloat/e5-base-v2")
#       8 reranker = CrossEncoderReranker(model="mixedbread-ai/mxbai-rerank-large-v1")
#      10 lotus.settings.configure(lm=lm, rm=rm, reranker=reranker)
#
# File /data/hdd1/users/jzerv/reproduced-systems/Lotus/lotus/models/sentence_transformers_rm.py:27, in SentenceTransformersRM.__init__(self, model, max_batch_size, normalize_embeddings, device, factory_string, metric)
#      25 self.max_batch_size: int = max_batch_size
#      26 self.normalize_embeddings: bool = normalize_embeddings
# ---> 27 self.transformer: SentenceTransformer = SentenceTransformer(model, device=device)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:287, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data)
#     278         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     280 if is_sentence_transformer_model(
#     281     model_name_or_path,
#     282     token,
#    (...)
#     285     local_files_only=local_files_only,
#     286 ):
# --> 287     modules = self._load_sbert_model(
#     288         model_name_or_path,
#     289         token=token,
#     290         cache_folder=cache_folder,
#     291         revision=revision,
#     292         trust_remote_code=trust_remote_code,
#     293         local_files_only=local_files_only,
#     294         model_kwargs=model_kwargs,
#     295         tokenizer_kwargs=tokenizer_kwargs,
#     296         config_kwargs=config_kwargs,
#     297     )
#     298 else:
#     299     modules = self._load_auto_model(
#     300         model_name_or_path,
#     301         token=token,
#    (...)
#     308         config_kwargs=config_kwargs,
#     309     )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:1487, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1484     if config_kwargs:
#    1485         kwargs["config_args"].update(config_kwargs)
# -> 1487     module = Transformer(model_name_or_path, cache_dir=cache_folder, **kwargs)
#    1488 else:
#    1489     # Normalize does not require any files to be loaded
#    1490     if module_class == Normalize:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:54, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path)
#      51     config_args = {}
#      53 config = AutoConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir)
# ---> 54 self._load_model(model_name_or_path, config, cache_dir, **model_args)
#      56 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      57     tokenizer_args["model_max_length"] = max_seq_length
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:85, in Transformer._load_model(self, model_name_or_path, config, cache_dir, **model_args)
#      83     self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#      84 else:
# ---> 85     self.auto_model = AutoModel.from_pretrained(
#      86         model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#      87     )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/transformers/modeling_utils.py:262, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     260 old_dtype = torch.get_default_dtype()
#     261 try:
# --> 262     return func(*args, **kwargs)
#     263 finally:
#     264     torch.set_default_dtype(old_dtype)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/transformers/modeling_utils.py:3970, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3967         raise
#    3968     except Exception as e:
#    3969         # For any other exception, we throw a generic error.
# -> 3970         raise EnvironmentError(
#    3971             f"Can't load the model for '{pretrained_model_name_or_path}'. If you were trying to load it"
#    3972             " from 'https://huggingface.co/models', make sure you don't have a local directory with the"
#    3973             f" same name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a"
#    3974             f" directory containing a file named {_add_variant(WEIGHTS_NAME, variant)},"
#    3975             f" {TF2_WEIGHTS_NAME}, {TF_WEIGHTS_NAME} or {FLAX_WEIGHTS_NAME}."
#    3976         ) from e
#    3978 if is_local:
#    3979     logger.info(f"loading weights file {archive_file}")
#
# OSError: Can't load the model for 'intfloat/e5-base-v2'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'intfloat/e5-base-v2' is the correct path to a directory containing a file named pytorch_model.bin, tf_model.h5, model.ckpt or flax_model.msgpack.
